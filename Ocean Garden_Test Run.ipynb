# %%
import tkinter as tk
from tkinter import ttk
from tkinter import *
from tkinter import OptionMenu, StringVar
import PIL
from PIL import ImageTk, Image
import imageio

# %%
origin = tk.Tk()
origin.title("Welcome")

canvas = tk.Canvas(origin, height=1080, width=1920, bg='#013220')
canvas.pack()

def resize_image(image_path, basewidth):
    image = Image.open(image_path)
    wpercent = basewidth / float(image.size[0])
    hsize = int(float(image.size[1]) * float(wpercent))
    resized_image = image.resize((basewidth, hsize), PIL.Image.Resampling.LANCZOS)
    return ImageTk.PhotoImage(resized_image)

def create_image(canvas, image_path, x, y, basewidth):
    photo = resize_image(image_path, basewidth)
    item = canvas.create_image(x, y, anchor='nw', image=photo)
    return item, photo

def create_text_widget(canvas, text, x, y, W, H):
    text_widget = tk.Text(origin, wrap=tk.WORD, width = W, height = H, font=('Calibri', 12), bg='#30513E', fg="white")
    text_widget.insert(tk.END, text)
    text_widget.place(x=x, y=y)
    canvas.create_window(x, y, anchor='nw', window=text_widget, tags="text_widget")


# Overlay Phytoplankton background
item0, photo0 = create_image(canvas, r"Resources\cyanobateria_baltic.png", 1150, 0, 550)
item1, photo1 = create_image(canvas, r"Resources\phytoplankton_baltic.png", 850, 0, 400)
item2, photo2 = create_image(canvas, r"Resources\plankton1.png", 490, 0, 420)
item3, photo3 = create_image(canvas, r"Resources\plankton.png", 100, 0, 300)

item_0, item_1, item_dia, item_diono, item_cyano, item_cocco, item_algae, item_ocean  = None, None, None, None, None, None, None, None
photo_0, photo_1, photo_dia, photo_diono, photo_cyano, photo_cocco, photo_algae, photo_ocean = None, None, None, None, None, None, None, None
def phytoplankton(event):
    phytoplankton_option = clicked.get()
    

    # Animate the disappearance of item0, item1, and item2
    for i in range(100):  # Adjust the range based on the desired animation speed
        canvas.move(item0, 3, 0)  # Move item0 upwards
        canvas.move(item1, 3, 0)  # Move item1 upwards
        canvas.move(item2, 3, 0)  # Move item2 upwards
        origin.update()  # Update the canvas to show the movement
        origin.after(5)  # Adjust the delay (in milliseconds) between each animation frame
    # Hide the images after animation
    canvas.itemconfig(item0, state="hidden")
    canvas.itemconfig(item1, state="hidden")
    canvas.itemconfig(item2, state="hidden")

    global item_0, photo_0, item_1, photo_1, item_dia, photo_dia, item_diono, photo_diono, item_cyano, photo_cyano, item_cocco, photo_cocco, item_algae, photo_algae, item_ocean, photo_ocean
    canvas.delete(item_0, photo_0, item_1, photo_1, item_dia, photo_dia, item_diono, photo_diono, item_cyano, photo_cyano, item_cocco, photo_cocco, item_algae, photo_algae, item_ocean, photo_ocean) 
    
    item_0, item_1, item_dia, item_diono, item_cyano, item_cocco, item_algae, item_ocean  = None, None, None, None, None, None, None, None
    photo_0, photo_1, photo_dia, photo_diono, photo_cyano, photo_cocco, photo_algae, photo_ocean = None, None, None, None, None, None, None, None
    
    canvas.delete("text_widget")

    if phytoplankton_option == option[0]: 
        item_0, photo_0 = create_image(canvas, r"Resources\cycle.png", 600, 50, 900)
        infos_0 = "We take great pride in being among the oldest microscopic organisms that contributed to the formation of life for all creatures on Earth and were also among the first photosynthesizers. Around 1.6 billion years ago, Earth provided us with plenty of our favorite food, and in return, we released oxygen and dimethyl sulfide as by-products. Today, the 21% oxygen constituent in Earth's atmosphere is the result of our efforts (and those of our ancestors!), shaping you as you gaze at your tiny computer screen now!"
        create_text_widget(canvas, infos_0, 600, 670, 112, 4)

    elif phytoplankton_option == option[1]: 
        item_1, photo_1 = create_image(canvas, r"Resources\plankton_cycle.png", 600, 0, 800)
        infos_1 = "As the sun rises, we begin our daily consumption of our favorite food, carbon dioxide (CO2). I suppose you humans call our intricate eating process 'photosynthesis'. To fill our bellies, we absorb sunlight, carbon dioxide, and water, and in return, we produce oxygen and other by-products. Here's a fun fact: did you know that 1 kg of cyanobacteria (our relatives!) can absorb up to 1.83 kg of carbon dioxide? This means that 12 kg of cyanobacteria can compensate for up to 22 kg of CO2, equivalent to the CO2 absorption of one mature tree per year. Additionally, we release Dimethyl Sulfide (DMS), which apparently is astronomers' favorite component to study when exploring habitable exoplanets!"
        create_text_widget(canvas, infos_1, 520, 680, 117, 5)

    elif phytoplankton_option == option[2]:
        item_dia, photo_dia = create_image(canvas, r"Resources\diatom.png", 480, 15, 350)
        infos_dia = "Here is a picture of me, my brothers and sisters, Diatoms! We are known for our unique frustules and diversity, with over 100,000 species. Our fossilized remains, diatomaceous earth, have various applications for human industry, including filtration, insulation, and even in the production of dynamite."
        create_text_widget(canvas, infos_dia, 480, 250, 43, 7)
    
        item_diono, photo_diono = create_image(canvas, r"Resources\dionoflangellate.png", 1171, 10, 350)
        infos_diono = "We are oceanic phytoplankton known as Dinoflagellates! As Dinoflagellates, we are renowned for our unique spinning movement, driven by two flagella! Humans are quite fond of us because we exhibit bioluminescence, emitting a beautiful blue-green light. This phenomenon results from a chemical reaction within our cells and serves both as a defense mechanism and a way to attract prey!"
        create_text_widget(canvas, infos_diono, 1175, 250, 43, 9)

        item_cyano, photo_cyano = create_image(canvas, r"Resources\cyanobacteria.png", 480, 410, 350)
        infos_cyano = "We're Cyanobacteria, recognized for our vibrant blue-green hue. As prokaryotic microorganisms, we thrive in various environments. Thanks to our CO2 concentration abilities, 1 kg of us can absorb 1.83 kg of CO2. For an EU citizen traveling 27 km daily, using 1 kg of us can offset their extra CO2 emissions, given a Tesla's emission rate of 0.066 kg CO2 per km!"
        create_text_widget(canvas, infos_cyano, 477, 640, 44, 7)

        item_cocco, photo_cocco = create_image(canvas, r"Resources\coccolithophore.png", 1170, 430, 350)
        infos_cyano = "We are Coccolithophores, another oceanic phytoplankton known for coccoliths. Our collective activity contributes significantly to Earth's atmospheric balance through photosynthesis. You can see us from space because of our milky, chalky waters that we create in vast blooms."
        create_text_widget(canvas, infos_cyano, 1171, 660, 44, 6)

        item_algae, photo_algae = create_image(canvas, r"Resources\algae.png", 835, 220, 330)
        infos_algae = "I am one of kind of diatoms, known for the nickname -jewels of the sea-. Beyond our beauty, we serve a vital purpose. When we perish, the transatlantic wind carries our dust to shore, enriching the entire Amazon Basin. We contribute 20 to 50 percent of Earth's oxygen, process 6.5 billion tons of silicon annually, and create nearly half of the oceans' organic material. Thanks to our cyanobacterial endosymbionts, we convert air's nitrogen through a unique urea cycle. When cared for, we are able yield a family of 68-130 by day six!"
        create_text_widget(canvas, infos_algae, 835, 375, 41, 12)
    
    elif phytoplankton_option == option[3]:
        item_ocean, photo_ocean = create_image(canvas,r"Resources\us_in_ocean.png", 500, 80, 1000)
        infos_ocean = "We, phytoplankton, can spread across hundreds and sometimes thousands of kilometers in the northern basins of the North Atlantic and Arctic Oceans every summer, thriving in nutrient-rich and cooler waters. Using Earth's satellites, scientists can observe our population density during late spring and early summer in the North Sea. However, warm seas can affect our productivity in oxygen production. Despite being microscopic, we play a crucial role in producing oxygen, contributing to efforts against climate change!"
        create_text_widget(canvas, infos_ocean, 500, 580, 125, 4)

    elif phytoplankton_option == option[4]:
        create_text_widget(canvas, "‌Ray, S., Abraham, J., Jordan, N., Lindsay, M. and Chauhan, N. (2022). Synthetic, Photosynthetic, and Chemical Strategies to Enhance Carbon Dioxide Fixation. C, 8(1), p.18. doi:https://doi.org/10.3390/c8010018.", 490, 20, 120, 25)
        create_text_widget(canvas, "European Environment Agency (2012). Trees help tackle climate change. [online] European Environment Agency. Available at: https://www.eea.europa.eu/articles/forests-health-and-climate-change/key-facts/trees-help-tackle-climate-change.", 490, 70, 120, 5)
        create_text_widget(canvas, "www.eea.europa.eu. (2022). CO2 performance of new passenger cars in Europe. [online] Available at: https://www.eea.europa.eu/ims/co2-performance-of-new-passenger.", 490, 120, 120, 5)
        create_text_widget(canvas, "transport.ec.europa.eu. (n.d.). New Mobility Patterns Study: insights into passenger mobility and urban logistics. [online] Available at: https://transport.ec.europa.eu/news-events/news/new-mobility-patterns-study-insights-passenger-mobility-and-urban-logistics-2022-12-20_en [Accessed 8 Oct. 2023].", 490, 170, 120, 5)
        create_text_widget(canvas, "NASA (2023). Carbon Dioxide C Sarkar, S., Constantinou, S., Holmberg, M., Piette, A. and Moses, J.I. (2023). Carbon-bearing Molecules in a Possible Hycean Atmosphere. arXiv (Cornell University). doi:https://doi.org/10.48550/arxiv.2309.05566.", 490, 280, 120, 5)
        create_text_widget(canvas, "‌Chami, R., Cosimano, T., FullenKamp, C. and Oztosun, S. (2019). Nature’s Solution to Climate Change – IMF F&D. [online] Ioncentration | NASA Global Climate Change. [online] Climate Change: Vital Signs of the Planet. Available at: https://climate.nasa.gov/vital-signs/carbon-dioxide/.", 490, 230, 120, 5)
        create_text_widget(canvas, "Nikku Madhusudhan,MF. Available at: https://www.imf.org/en/Publications/fandd/issues/2019/12/natures-solution-to-climate-change-chami.", 490, 330, 120, 5)
        create_text_widget(canvas, "Anon, (2015). The importance of plankton - Blue Planet Society. [online] Available at: https://www.blueplanetsociety.org/the-importance-of-plankton/ [Accessed 8 Oct. 2023].", 490, 380, 120, 4)
        create_text_widget(canvas, "Climate Change: Vital Signs of the Planet. (n.d.). Summer blooms in the Baltic. [online] Available at: https://climate.nasa.gov/climate_resources/170/summer-blooms-in-the-baltic/ [Accessed 8 Oct. 2023].", 490, 430, 120, 3)
        create_text_widget(canvas, "Wikipedia Contributors (2019). Diatom. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Diatom.", 490, 480, 120, 12)
        create_text_widget(canvas, "earthobservatory.nasa.gov. (2020). Beguiling Bloom in The Baltic Sea. [online] Available at: https://earthobservatory.nasa.gov/images/147135/beguiling-bloom-in-the-baltic-sea.", 490,505, 120, 3)
        create_text_widget(canvas, "Wikipedia Contributors (2019). Biological pump. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Biological_pump.", 490, 555, 120,3)
        create_text_widget(canvas, "forums.zeiss.com. (n.d.). ZEISS microscopes reveal the hidden world of plankton - ZEISS Microscopy Developer Community. [online] Available at: https://forums.zeiss.com/microscopy/community/viewtopic.php?t=2466 [Accessed 8 Oct. 2023].", 490, 580, 120, 4)
        create_text_widget(canvas, "Motic Microscopes. (n.d.). Diatoms - Nature’s Jewels viewed with a Microscope. [online] Available at: https://moticmicroscopes.com/blogs/articles/diatoms-nature-s-jewels-viewed-with-a-microscope.", 490, 630, 120, 4)
        create_text_widget(canvas, "Plantlet. (2020). Pyrrophyta: The Fire Algae (Dinoflagellate). [online] Available at: https://plantlet.org/pyrrophyta-the-fire-algae-dinoflagellate/.", 490, 680, 120, 3)
        create_text_widget(canvas, "www.youtube.com. (n.d.). Feeding the Sea: Phytoplankton Fuel Ocean Life. [online] Available at: https://www.youtube.com/watch?v=AWfebk0_auY&t=64s [Accessed 8 Oct. 2023].", 490, 710, 120, 3)

about_us_frame = tk.Frame(origin, bg="#013220")
about_us_frame.place(relx=0.01, rely=0.35, relheight=0.34, relwidth=0.3)

option = ["Our contribution",
          "A day in our life", 
          "Our brothers and sisters",
          "Us in the ocean",
          "Resources"]

clicked = StringVar()
clicked.set(option[0])
drop = OptionMenu(origin, clicked, *option)
drop.place(relx=0.04, rely=0.69, relheight=0.05, relwidth=0.12)

button = tk.Button(canvas, text='Get Info')
button.bind('<Button-1>', phytoplankton)
button.place(relx=0.16, rely=0.69, relheight=0.05, relwidth=0.1)

text = 'Welcome! \n\n\n We are happy that you visit us, Phytoplankton! \n\n\n What do you want to know about us?'
initial_label = tk.Label(about_us_frame, text=text, font=('Calibri', 18), bg='#013220', fg="white")
initial_label.pack(side='left')

origin.mainloop()
